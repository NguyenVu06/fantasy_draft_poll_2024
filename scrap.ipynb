# %%
import pandas as pd

# %%
df = pd.read_clipboard()

# %%
df.columns
# Out:
# Index(['Voted At', 'Player'], dtype='object')

# %%
df['Player'].unique()
# Out:
# array(['Nguyen (2x champ)', 'Nick (commish)', 'Tuan', 'David', 'Minh',
#        'Dan'], dtype=object)
